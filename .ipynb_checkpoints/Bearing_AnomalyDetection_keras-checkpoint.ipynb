# %%
import pandas as pd
#df_healthy = pd.read_csv('result_healthy_pandas.csv', engine='python', header=None)
#df_healthy.head()
# Out:
#    0   1         2         3
# 0  0  98  0.046104  0.023216
# 1  1  98 -0.037134  0.081155
# 2  2  98 -0.089496  0.095331
# 3  3  98 -0.084906  0.091016
# 4  4  98 -0.038594  0.038625

# %%
import ibmos2spark

# @hidden_cell
credentials = {
    'endpoint': 'https://s3-api.us-geo.objectstorage.service.networklayer.com',
    'api_key': '',
    'service_id': '',
    'iam_service_endpoint': 'https://iam.bluemix.net/oidc/token'}

configuration_name = ''
cos = ibmos2spark.CloudObjectStorage(sc, credentials, configuration_name, 'bluemix_cos')

from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
# Out:
# Waiting for a Spark session to start...

# %%
df_healthy=spark.read.parquet(cos.url('ewr_healthy.parquet', ''))

# %%
df_faulty=spark.read.parquet(cos.url('ewr_faulty.parquet', ''))

# %%
df_healthy.show()
# Out:
# +---+---+--------------------+--------------------+
# |_c0|_c1|                 _c2|                 _c3|
# +---+---+--------------------+--------------------+
# |  0| 98|0.023216363636363632|            0.046104|
# |  1| 98| 0.08115454545454545|-0.03713353846153846|
# |  2| 98| 0.09533090909090909|-0.08949599999999999|
# |  3| 98| 0.09101636363636363|-0.08490646153846154|
# |  4| 98|0.038625454545454546|-0.03859384615384615|
# |  5| 98|0.027120000000000002| 0.02545107692307692|
# |  6| 98| 0.05013090909090909|0.040679999999999994|
# |  7| 98|0.045816363636363634|0.042557538461538466|
# |  8| 98|0.014176363636363636|0.038176615384615385|
# |  9| 98|-0.03780363636363636| 0.04401784615384615|
# | 10| 98|-0.08526363636363636| 0.04214030769230769|
# | 11| 98|-0.06985454545454545|-0.01147384615384...|
# | 12| 98|0.003081818181818...|-0.07677046153846154|
# | 13| 98| 0.03985818181818182|-0.14707384615384617|
# | 14| 98| 0.04951454545454545|-0.15291507692307693|
# | 15| 98|0.020956363636363638|-0.09554584615384615|
# | 16| 98|-0.00862909090909091|-0.03087507692307...|
# | 17| 98|0.020545454545454544| 0.02899753846153846|
# | 18| 98|0.038419999999999996| 0.03129230769230769|
# | 19| 98| 0.02527090909090909| 0.01856676923076923|
# +---+---+--------------------+--------------------+
# only showing top 20 rows

# %%
df_healthy.createOrReplaceTempView('df_healthy')

# %%
df_faulty.createOrReplaceTempView('df_faulty')

# %%
df_faulty.show()
# Out:
# +---+---+--------------------+--------------------+
# |_c0|_c1|                 _c2|                 _c3|
# +---+---+--------------------+--------------------+
# |  0|108|  0.2226985628742515|-0.09738545454545454|
# |  1|108| 0.09323776447105789|             -0.1808|
# |  2|108| -0.1465164870259481| -0.2336018181818182|
# |  3|108|  0.1772167265469062|-0.10211090909090909|
# |  4|108|   0.248525748502994|-0.03328363636363636|
# |  5|108|-0.07114658682634731| -0.1296418181818182|
# |  6|108|-0.12133904191616766|-0.00862909090909091|
# |  7|108|-0.01396942115768463|             0.02938|
# |  8|108| 0.12020199600798404|-0.06266363636363637|
# |  9|108| 0.07130902195608782| 0.05732181818181818|
# | 10|108| 0.11467920159680639| 0.08834545454545455|
# | 11|108| 0.10347117764471057|0.027120000000000002|
# | 12|108|-0.10233413173652695| 0.08855090909090908|
# | 13|108|-0.06546135728542915|0.008218181818181819|
# | 14|108|-0.06854762475049901| 0.11649272727272726|
# | 15|108| -0.1020092614770459|             0.42488|
# | 16|108|-0.12052686626746507|  0.2933890909090909|
# | 17|108|-0.12881105788423153| 0.10560363636363636|
# | 18|108| 0.12783644710578843| 0.18470363636363635|
# | 19|108| 0.45091992015968063| 0.05773272727272727|
# +---+---+--------------------+--------------------+
# only showing top 20 rows

# %%
#df_faulty = pd.read_csv('result_faulty_pandas.csv', engine='python', header=None)
#df_faulty.head()
# Out:
#    0   1         2         3
# 0  0  98  0.046104  0.023216
# 1  1  98 -0.037134  0.081155
# 2  2  98 -0.089496  0.095331
# 3  3  98 -0.084906  0.091016
# 4  4  98 -0.038594  0.038625

# %%
import numpy as np
from numpy import concatenate
from matplotlib import pyplot
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
import sklearn
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import Callback
from keras.models import Sequential
from keras.layers import LSTM, Dense, Activation
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import time
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))

# %%
timesteps = 100
dim = 2
lossHistory = LossHistory()
# design network

model = Sequential()
model.add(LSTM(50,input_shape=(timesteps,dim),return_sequences=True))
model.add(Dense(2))
model.compile(loss='mae', optimizer='adam')

def train(data):
    model.fit(data, data, epochs=20, batch_size=72, validation_data=(data, data), verbose=1, shuffle=False,callbacks=[lossHistory])

def score(data):
    yhat =  model.predict(data)
    return yhat

# %%
#some learners constantly reported 502 errors in Watson Studio. 
#This is due to the limited resources in the free tier and the heavy resource consumption of Keras.
#This is a workaround to limit resource consumption

from keras import backend as K

K.set_session(K.tf.Session(config=K.tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)))

# %%
def get_recording(df,file_id):
    recording = np.array(df.orderBy(df['_c0']).where(df['_c1'] == file_id).select('_c2','_c3').rdd.map(lambda row:np.array([row._c2,row._c3])).collect())
    return recording
#np.array(df.sort_values(by=0, ascending=True).loc[df[1] == file_id].drop(0,1).drop(1,1))

# %%
def create_trimmed_recording(df,file_id):
    timesteps = 100
    recording = np.array(df.orderBy(df['_c0']).where(df['_c1'] == file_id).select('_c2','_c3').rdd.map(lambda row:np.array([row._c2,row._c3])).collect())
    samples = len(recording)
    trim = samples % 100
    recording_trimmed = recording[:samples-trim]
    recording_trimmed.shape =(int((samples-trim)/timesteps),timesteps,dim)
    #(int((samples-trim)/timesteps),timesteps,dim)
    return recording_trimmed

# %%
import numpy as np
healthy_sample = get_recording(df_healthy,98)
faulty_sample = get_recording(df_faulty,108)

# %%
len(faulty_sample)
# Out:
# 122917

# %%
len(healthy_sample)
# Out:
# 485643

# %%
file_ids = spark.sql('select distinct _c1 from df_healthy').rdd.map(lambda row:row._c1).collect()

# %%
start = time.time()
for file_id in file_ids:
    recording_trimmed = create_trimmed_recording(df_healthy,file_id)
    print("Staring training on %s" % (file_id))
    train(recording_trimmed)
    print("Finished training on %s after %s seconds" % (file_id,time.time()-start))

print("Finished job on after %s seconds" % (time.time()-start))
healthy_losses = lossHistory.losses
# Out:
# Staring training on 98
# Train on 4839 samples, validate on 4839 samples
# Epoch 1/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0415 - val_loss: 0.0332
# Epoch 2/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0243 - val_loss: 0.0165
# Epoch 3/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0103 - val_loss: 0.0085
# Epoch 4/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0053 - val_loss: 0.0044
# Epoch 5/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0039 - val_loss: 0.0071
# Epoch 6/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0035 - val_loss: 0.0031
# Epoch 7/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0026 - val_loss: 0.0023
# Epoch 8/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0016
# Epoch 9/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 10/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 11/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0012 - val_loss: 0.0028
# Epoch 12/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0025 - val_loss: 0.0029
# Epoch 13/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0021 - val_loss: 0.0016
# Epoch 14/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 15/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 16/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0013 - val_loss: 0.0012
# Epoch 17/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0014 - val_loss: 0.0013
# Epoch 18/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 19/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0012 - val_loss: 0.0010
# Epoch 20/20
# 4839/4839 [==============================] - 14s 3ms/step - loss: 0.0011 - val_loss: 0.0010
# Finished training on 98 after 304.2284128665924 seconds
# Staring training on 100
# Train on 4856 samples, validate on 4856 samples
# Epoch 1/20
# 4856/4856 [==============================] - 14s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 2/20
# 4856/4856 [==============================] - 14s 3ms/step - loss: 9.7787e-04 - val_loss: 8.9089e-04
# Epoch 3/20
# 4856/4856 [==============================] - 14s 3ms/step - loss: 9.4139e-04 - val_loss: 9.3970e-04
# Epoch 4/20
# 4856/4856 [==============================] - 14s 3ms/step - loss: 8.8233e-04 - val_loss: 5.4420e-04
# Epoch 5/20
# 4856/4856 [==============================] - 14s 3ms/step - loss: 5.9834e-04 - val_loss: 4.3648e-04
# Epoch 6/20
# 4856/4856 [==============================] - 14s 3ms/step - loss: 5.9860e-04 - val_loss: 8.3209e-04
# Epoch 7/20
# 4856/4856 [==============================] - 14s 3ms/step - loss: 7.7604e-04 - val_loss: 8.8077e-04
# Epoch 8/20
# 4856/4856 [==============================] - 14s 3ms/step - loss: 6.8312e-04 - val_loss: 4.8303e-04
# Epoch 13/20
# 2439/2439 [==============================] - 7s 3ms/step - loss: 3.3577e-04 - val_loss: 3.0670e-04
# Epoch 14/20
# 2439/2439 [==============================] - 7s 3ms/step - loss: 3.3351e-04 - val_loss: 3.0528e-04
# Epoch 15/20
# 2439/2439 [==============================] - 7s 3ms/step - loss: 3.3121e-04 - val_loss: 3.0616e-04
# Epoch 16/20
# 2439/2439 [==============================] - 7s 3ms/step - loss: 3.2913e-04 - val_loss: 3.0298e-04
# Epoch 17/20
# 2439/2439 [==============================] - 7s 3ms/step - loss: 3.2712e-04 - val_loss: 3.0260e-04
# Epoch 18/20
# 2439/2439 [==============================] - 7s 3ms/step - loss: 3.2511e-04 - val_loss: 3.0421e-04
# Epoch 19/20
# 2439/2439 [==============================] - 7s 3ms/step - loss: 3.2328e-04 - val_loss: 2.9871e-04
# Epoch 20/20
# 2439/2439 [==============================] - 7s 3ms/step - loss: 3.2146e-04 - val_loss: 2.9843e-04
# Finished training on 97 after 767.931764125824 seconds
# Finished job on after 767.9319689273834 seconds

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(healthy_losses)
plt.ylim(0,0.008)
ax.plot(range(0,size), healthy_losses, '-', color='blue', animated = True, linewidth=1)

# %%
file_ids = spark.sql('select distinct _c1 from df_faulty').rdd.map(lambda row:row._c1).collect()
start = time.time()
for file_id in file_ids:
    recording_trimmed = create_trimmed_recording(df_faulty,file_id)
    print("Staring training on %s" % (file_id))
    train(recording_trimmed)
    print("Finished training on %s after %s seconds" % (file_id,time.time()-start))

print("Finished job on after %s seconds" % (time.time()-start))
faulty_losses = lossHistory.losses
# Out:
# Staring training on 107
# Train on 1221 samples, validate on 1221 samples
# Epoch 1/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0031 - val_loss: 0.0025
# Epoch 2/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0023 - val_loss: 0.0021
# Epoch 3/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 4/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 5/20
# 1221/1221 [==============================] - 4s 3ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 6/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0016 - val_loss: 0.0015
# Epoch 7/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0015 - val_loss: 0.0014
# Epoch 8/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 9/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 10/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 11/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0012 - val_loss: 0.0011
# Epoch 12/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 13/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 14/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 9.7426e-04 - val_loss: 9.4133e-04
# Epoch 15/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 9.1502e-04 - val_loss: 8.8234e-04
# Epoch 16/20
# 1221/1221 [==============================] - 3s 3ms/step - loss: 8.5865e-04 - val_loss: 8.2882e-04
# Epoch 17/20
# Epoch 4/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 6.9386e-04 - val_loss: 7.4035e-04
# Epoch 5/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 6.7738e-04 - val_loss: 5.9848e-04
# Epoch 6/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 6.5450e-04 - val_loss: 7.6642e-04
# Epoch 7/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 6.5201e-04 - val_loss: 6.1414e-04
# Epoch 8/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 6.2910e-04 - val_loss: 6.8464e-04
# Epoch 9/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 6.1969e-04 - val_loss: 5.8883e-04
# Epoch 10/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 6.0472e-04 - val_loss: 6.5795e-04
# Epoch 11/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 6.0092e-04 - val_loss: 5.5420e-04
# Epoch 12/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.8416e-04 - val_loss: 6.3383e-04
# Epoch 13/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.7867e-04 - val_loss: 5.4032e-04
# Epoch 14/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.6614e-04 - val_loss: 6.1273e-04
# Epoch 15/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.6532e-04 - val_loss: 5.1991e-04
# Epoch 16/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.5035e-04 - val_loss: 5.7583e-04
# Epoch 17/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.4464e-04 - val_loss: 4.7276e-04
# Epoch 18/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.3974e-04 - val_loss: 5.8378e-04
# Epoch 19/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.3637e-04 - val_loss: 4.9616e-04
# Epoch 20/20
# 1219/1219 [==============================] - 3s 3ms/step - loss: 5.2423e-04 - val_loss: 5.5846e-04
# Finished training on 106 after 283.27914214134216 seconds
# Staring training on 105
# Train on 1212 samples, validate on 1212 samples
# Epoch 1/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 5.2772e-04 - val_loss: 4.9764e-04
# Epoch 2/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 5.2115e-04 - val_loss: 5.1717e-04
# Epoch 3/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 5.1194e-04 - val_loss: 4.7238e-04
# Epoch 4/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 5.1169e-04 - val_loss: 5.2764e-04
# Epoch 5/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 5.0879e-04 - val_loss: 4.8964e-04
# Epoch 6/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.9901e-04 - val_loss: 4.9773e-04
# Epoch 7/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.9281e-04 - val_loss: 4.3618e-04
# Epoch 8/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.9504e-04 - val_loss: 5.1379e-04
# Epoch 9/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.9237e-04 - val_loss: 4.6825e-04
# Epoch 10/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.8085e-04 - val_loss: 4.7948e-04
# Epoch 11/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.7888e-04 - val_loss: 4.3042e-04
# Epoch 12/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.7925e-04 - val_loss: 4.8635e-04
# Epoch 13/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.7813e-04 - val_loss: 4.4457e-04
# Epoch 14/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.6979e-04 - val_loss: 4.5557e-04
# Epoch 15/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.6541e-04 - val_loss: 4.2556e-04
# Epoch 16/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.6113e-04 - val_loss: 4.6791e-04
# Epoch 17/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.5363e-04 - val_loss: 4.2970e-04
# Epoch 18/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.4326e-04 - val_loss: 4.5290e-04
# Epoch 19/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.5323e-04 - val_loss: 3.8735e-04
# Epoch 20/20
# 1212/1212 [==============================] - 3s 3ms/step - loss: 4.6783e-04 - val_loss: 5.2050e-04
# Finished training on 105 after 376.2904987335205 seconds
# Finished job on after 376.2906725406647 seconds

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(healthy_losses+faulty_losses)
plt.ylim(0,0.001)
ax.plot(range(0,size), healthy_losses+faulty_losses, '-', color='blue', animated = True, linewidth=1)

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(healthy_sample)
ax.plot(range(0,size), healthy_sample[:,0], '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,size), healthy_sample[:,1], '-', color='blue', animated = True, linewidth=1)

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
size = len(faulty_sample)
ax.plot(range(0,size), faulty_sample[:,1], '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,size), faulty_sample[:,0], '-', color='blue', animated = True, linewidth=1)

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
ax.plot(range(0,500), healthy_sample[:500,0], '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,500), healthy_sample[:500,1], '-', color='blue', animated = True, linewidth=1)

# %%
fig, ax = plt.subplots(num=None, figsize=(14, 6), dpi=80, facecolor='w', edgecolor='k')
ax.plot(range(0,500), faulty_sample[:500,0], '-', color='red', animated = True, linewidth=1)
ax.plot(range(0,500), faulty_sample[:500,1], '-', color='blue', animated = True, linewidth=1)
